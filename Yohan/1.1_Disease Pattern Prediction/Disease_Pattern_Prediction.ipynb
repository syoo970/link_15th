# %%
import codecs
from bs4 import BeautifulSoup
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random, sys
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
# 30대 질병데이터 읽어오기 
df = pd.read_table('yang_30.txt', sep='\n', header = None)
df.columns = ['text']
df.head()
# Out:
#                                                 text
# 0   S OL766 KG504 SF108 WR405 ET321 RD201 IO789 O...
# 1   S FG308 PO276 FG371 KL365 QW987 LO103 LO103 P...
# 2   S WD675 RE385 PK765 GH791 KG341 ZA107 WR896 O...
# 3   S RE385 QO233 WY390 GH700 ZA107 KO109 WO378 O...
# 4   S QE931 QO102 GH791 SD398 ER389 QE277 OP345 G...

# %%
# 질병-가격 기록읽어오기 
dp_code = pd.read_csv('d_code.csv')
d_code = list(dp_code.d_code)
dp_code.head()
# Out:
#   d_code   price
# 0  KP345   71100
# 1  OK163  123000
# 2  QW987    3500
# 3  ER203   38800
# 4  OP167   68900

# %%
# 질병평균 가격표
dp_code_dic = dict(zip(dp_code.d_code , dp_code.price))
dp_code_dic
# Out:
# {'KP345': 71100,
#  'OK163': 123000,
#  'QW987': 3500,
#  'ER203': 38800,
#  'OP167': 68900,
#  'ER897': 33900,
#  'PO203': 4500,
#  'PK765': 6400,
#  'IO789': 45900,
#  'UY503': 3500,
#  'ER300': 3500,
#  'TY211': 14500,
#  'KL365': 11800,
#  'QA107': 28300,
#  'ET320': 22400,
#  'GH700': 3500,
#  'KG907': 20100,
#  'RD201': 48500,
#  'BN377': 21600,
#  'SF108': 3500,
#  'KG504': 3500,
#  'WD234': 44100,
#  'QO233': 59000,
#  'HD405': 3500,
#  'HK504': 56000,
#  'OL344': 60000,
#  'PL221': 65100,
#  'WY390': 3500,
#  'WD100': 95900,
#  'QY204': 17900,
#  'UY201': 111400,
#  'QE277': 46400,
#  'TR675': 63400,
#  'FG371': 13200,
#  'KO109': 108700,
#  'JV766': 107400,
#  'WO208': 3500,
#  'RE397': 3500,
#  'CV305': 88500,
#  'ZA780': 32800,
#  'SD308': 3500,
#  'WR405': 6300,
#  'LO103': 3500,
#  'WR117': 52500,
#  'ET650': 79700,
#  'WO900': 16400,
#  'PL250': 3500,
#  'RE567': 79100,
#  'PK244': 61600,
#  'UY980': 11000,
#  'KG766': 3800,
#  'OK211': 3500,
#  'KP843': 25100,
#  'TR508': 3500,
#  'TR109': 3500,
#  'HK377': 14700,
#  'GH433': 36300,
#  'QO349': 82000,
#  'WY107': 3500,
#  'WD599': 65700,
#  'ER119': 73700,
#  'HD433': 3500,
#  'OL766': 39500,
#  'RE385': 3500,
#  'QO102': 3500,
#  'OP345': 3500,
#  'PO276': 29500,
#  'PK213': 3500,
#  'UY109': 19500,
#  'ER389': 109800,
#  'TY901': 3500,
#  'SD388': 81800,
#  'LO976': 19600,
#  'FG391': 119300,
#  'WO188': 3500,
#  'OP350': 109700,
#  'GH211': 35400,
#  'QO743': 3500,
#  'KP321': 6300,
#  'WR789': 33600,
#  'UY112': 3500,
#  'WY504': 161100,
#  'QO304': 7000,
#  'WD675': 3500,
#  'ET321': 3200,
#  'RE577': 69400,
#  'ZA107': 24500,
#  'GH791': 58600,
#  'JV109': 9100,
#  'CV751': 3500,
#  'KG341': 135900,
#  'WO378': 46500,
#  'PL890': 29000,
#  'WR896': 58000,
#  'SD398': 3500,
#  'FG308': 46800,
#  'JV765': 24700,
#  'QE931': 10500,
#  'TY341': 80000,
#  'WR321': 95500}

# %%
all_text = ''
for str in df.text:
        all_text = all_text + ' ' + str

text = all_text
print('훈련 데이터: ', len(text))
# Out:
# 훈련 데이터:  946418

# %%
# 질병사전 구축하기 
text_split = text.split(" ")
chars = sorted(list(set(text_split)))
print('질병코드의 종류:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))  
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# 질병코드의 종류: 103

# %%
char_indices
# Out:
# {'': 0,
#  'BN377': 1,
#  'CV305': 2,
#  'CV751': 3,
#  'E': 4,
#  'ER119': 5,
#  'ER203': 6,
#  'ER300': 7,
#  'ER389': 8,
#  'ER897': 9,
#  'ET320': 10,
#  'ET321': 11,
#  'ET650': 12,
#  'FG308': 13,
#  'FG371': 14,
#  'FG391': 15,
#  'GH211': 16,
#  'GH433': 17,
#  'GH700': 18,
#  'GH791': 19,
#  'HD405': 20,
#  'HD433': 21,
#  'HK377': 22,
#  'HK504': 23,
#  'IO789': 24,
#  'JV109': 25,
#  'JV765': 26,
#  'JV766': 27,
#  'KG341': 28,
#  'KG504': 29,
#  'KG766': 30,
#  'KG907': 31,
#  'KL365': 32,
#  'KO109': 33,
#  'KP321': 34,
#  'KP345': 35,
#  'KP843': 36,
#  'LO103': 37,
#  'LO976': 38,
#  'OK163': 39,
#  'OK211': 40,
#  'OL344': 41,
#  'OL766': 42,
#  'OP167': 43,
#  'OP345': 44,
#  'OP350': 45,
#  'PK213': 46,
#  'PK244': 47,
#  'PK765': 48,
#  'PL221': 49,
#  'PL250': 50,
#  'PL890': 51,
#  'PO203': 52,
#  'PO276': 53,
#  'QA107': 54,
#  'QE277': 55,
#  'QE931': 56,
#  'QO102': 57,
#  'QO233': 58,
#  'QO304': 59,
#  'QO349': 60,
#  'QO743': 61,
#  'QW987': 62,
#  'QY204': 63,
#  'RD201': 64,
#  'RE385': 65,
#  'RE397': 66,
#  'RE567': 67,
#  'RE577': 68,
#  'S': 69,
#  'SD308': 70,
#  'SD388': 71,
#  'SD398': 72,
#  'SF108': 73,
#  'TR109': 74,
#  'TR508': 75,
#  'TR675': 76,
#  'TY211': 77,
#  'TY341': 78,
#  'TY901': 79,
#  'UY109': 80,
#  'UY112': 81,
#  'UY201': 82,
#  'UY503': 83,
#  'UY980': 84,
#  'WD100': 85,
#  'WD234': 86,
#  'WD599': 87,
#  'WD675': 88,
#  'WO188': 89,
#  'WO208': 90,
#  'WO378': 91,
#  'WO900': 92,
#  'WR117': 93,
#  'WR321': 94,
#  'WR405': 95,
#  'WR789': 96,
#  'WR896': 97,
#  'WY107': 98,
#  'WY390': 99,
#  'WY504': 100,
#  'ZA107': 101,
#  'ZA780': 102}

# %%
indices_char
# Out:
# {0: '',
#  1: 'BN377',
#  2: 'CV305',
#  3: 'CV751',
#  4: 'E',
#  5: 'ER119',
#  6: 'ER203',
#  7: 'ER300',
#  8: 'ER389',
#  9: 'ER897',
#  10: 'ET320',
#  11: 'ET321',
#  12: 'ET650',
#  13: 'FG308',
#  14: 'FG371',
#  15: 'FG391',
#  16: 'GH211',
#  17: 'GH433',
#  18: 'GH700',
#  19: 'GH791',
#  20: 'HD405',
#  21: 'HD433',
#  22: 'HK377',
#  23: 'HK504',
#  24: 'IO789',
#  25: 'JV109',
#  26: 'JV765',
#  27: 'JV766',
#  28: 'KG341',
#  29: 'KG504',
#  30: 'KG766',
#  31: 'KG907',
#  32: 'KL365',
#  33: 'KO109',
#  34: 'KP321',
#  35: 'KP345',
#  36: 'KP843',
#  37: 'LO103',
#  38: 'LO976',
#  39: 'OK163',
#  40: 'OK211',
#  41: 'OL344',
#  42: 'OL766',
#  43: 'OP167',
#  44: 'OP345',
#  45: 'OP350',
#  46: 'PK213',
#  47: 'PK244',
#  48: 'PK765',
#  49: 'PL221',
#  50: 'PL250',
#  51: 'PL890',
#  52: 'PO203',
#  53: 'PO276',
#  54: 'QA107',
#  55: 'QE277',
#  56: 'QE931',
#  57: 'QO102',
#  58: 'QO233',
#  59: 'QO304',
#  60: 'QO349',
#  61: 'QO743',
#  62: 'QW987',
#  63: 'QY204',
#  64: 'RD201',
#  65: 'RE385',
#  66: 'RE397',
#  67: 'RE567',
#  68: 'RE577',
#  69: 'S',
#  70: 'SD308',
#  71: 'SD388',
#  72: 'SD398',
#  73: 'SF108',
#  74: 'TR109',
#  75: 'TR508',
#  76: 'TR675',
#  77: 'TY211',
#  78: 'TY341',
#  79: 'TY901',
#  80: 'UY109',
#  81: 'UY112',
#  82: 'UY201',
#  83: 'UY503',
#  84: 'UY980',
#  85: 'WD100',
#  86: 'WD234',
#  87: 'WD599',
#  88: 'WD675',
#  89: 'WO188',
#  90: 'WO208',
#  91: 'WO378',
#  92: 'WO900',
#  93: 'WR117',
#  94: 'WR321',
#  95: 'WR405',
#  96: 'WR789',
#  97: 'WR896',
#  98: 'WY107',
#  99: 'WY390',
#  100: 'WY504',
#  101: 'ZA107',
#  102: 'ZA780'}

# %%
# 전체 훈련 데이터를 쪼개어서 문장구조로 만들기
maxlen = 5
step = 1
sentences = []
next_chars = []

for i in range(0, len(text_split) - maxlen, step):
    sentences.append(" ".join(text_split[i: i + maxlen]))
    next_chars.append(text_split[i + maxlen])
    
print('학습할 질병패턴의 수:', len(sentences))
X = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence.split(" ")):
        X[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 학습할 질병패턴의 수: 179399

# %%
# 모델 구축하기(LSTM)
print('LSTM 모델을 만들어 본다....')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))
optimizer = RMSprop(lr=0.015)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# LSTM 모델을 만들어 본다....

# %%
# 후보추출
def sample(preds, temp=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temp
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
# 질병코드 단어생성하기 
generated_all = []
for iteration in range(1, 8):
    print()
    print('반복번호 =', iteration)
    model.fit(X, y, batch_size=128, epochs=1)
    
    # 옵션을 다르게 하여 다양한 방법으로 생성하기
    for diversity in [1.4 , 1.6 , 1.8 , 2.0 , 2.2 , 2.4 , 2.6]:
        print()
        print('추출옵션 : ', diversity)
        generated = ''
        #sentence = text[start_index: start_index + maxlen]
        #sentence = "OL766 KG504 SF108"
        sentence = "S FG391"
        generated += sentence
        print('질병시작패턴 = "' + sentence + '"')
        sys.stdout.write(generated)
        
        # 질병코드 자동생성
        for i in range(35):      #문장의 평균 단어의 수(1년동안 질병의 코드의 수) 
            x = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence.split(" ")):
                x[0, t, char_indices[char]] = 1.
                
            # 다음에 올 질병코드를 예측하기
            preds = model.predict(x, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
            
            # 30대 예상질병코드 출력하기
            generated += " " + next_char
            sentence = " ".join(sentence.split(" ")[1:]) + " " + next_char
            sys.stdout.write(" " + next_char)
            sys.stdout.flush()
            
            if next_char == "E":
                generated_all.append(generated)
                break
        print()
# Out:
# 반복번호 = 1
# Epoch 1/1
# 179399/179399 [==============================] - 14s 77us/step - loss: 4.0426
#
# 추출옵션 :  1.4
# 질병시작패턴 = "S FG391"
# S FG391 HD433 QA107 KG341 WR789 QO233 KP843 ZA780 QA107 WR321 E
#
# 추출옵션 :  1.6
# 질병시작패턴 = "S FG391"
# S FG391 WY390 WD100 WD675 QW987 KP321 WR117 QO349 PL890 WO900 WR896 QO743 WD675 E
#
# 추출옵션 :  1.8
# 질병시작패턴 = "S FG391"
# S FG391 QA107 TY901 OP350 WR321 HD433 ZA780 LO103 HD405 E
#
# 추출옵션 :  2.0
# 질병시작패턴 = "S FG391"
# S FG391 WO188 JV765 QO743 KP345 WO188 TY901 LO976 TY211 OK211 JV765 KG504 WY504 JV766 FG308 WR789 KP843 KG766 JV765 QO349 PK213 TY341 ET320 WR321 ET320 UY980 WR405 PL890 PK213 QE277 LO103 E
#
# 추출옵션 :  2.2
# 질병시작패턴 = "S FG391"
# S FG391 PL250 RE577 QE277 OK211 SD398 WR405 WR405 OK211 KP345 QO349 CV751 SD388 PO203 ER203 KP843 TY211 KP321 ER300 KP321 CV305 WR405 ER300 OK211 KP345 RE385 QE277 CV305 ER897 OL766 BN377 OK211 KP345 ER897 WD675 FG391
#
# 추출옵션 :  2.4
# 질병시작패턴 = "S FG391"
# S FG391 GH791 UY109 LO103 LO103 TY341 PO203 WR896 SF108 WY390 ER203 ET321 PK213 HD405 SD398 GH791 QE931 E
#
# 추출옵션 :  2.6
# 질병시작패턴 = "S FG391"
# S FG391 GH433 WO378 GH433 HD433 SD308 KP345 PK765 RE577 FG308 WD599 QY204 PO276 QO349 KG504 GH791 PL890 KL365 PK213 PL250 GH791 QY204 ZA107 WR789 RD201 LO103 JV766 PL221 KG504 QO349 TY901 WR321 QA107 ZA780 KG766 WY390
#
# 반복번호 = 2
# Epoch 1/1
# 179399/179399 [==============================] - 14s 78us/step - loss: 4.0232
#
# 추출옵션 :  1.4
# 질병시작패턴 = "S FG391"
# S FG391 WD599 SD398 KP345 PO276 KP321 OP167 E
#
# 추출옵션 :  1.6
# 질병시작패턴 = "S FG391"
# S FG391 TR675 LO103 QY204 WD599 OP345 WD599 ET320 HD405 KG504 HK504 UY109 BN377 SF108 JV765 RD201 TY211 KG341 E
#
# 추출옵션 :  1.8
# 질병시작패턴 = "S FG391"
# S FG391 UY109 OP350 TY211 KG504 ER389 QY204 QE277 PK765 JV765 GH700 IO789 ER119 QA107 QE277 RD201 ET320 QO743 WR405 KO109 WR117 RE567 QO102 WR896 OK211 HD433 ZA780 PL250 RE567 HK377 ER300 IO789 UY109 KG907 CV751 RE385
#
# 추출옵션 :  2.0
# 질병시작패턴 = "S FG391"
# S FG391 JV766 OL766 WD599 QO349 OP350 SD388 QO233 QE931 UY201 TR109 LO103 HD405 LO103 PL890 TY901 OL766 PO203 RD201 KG341 FG371 TR109 WO900 ZA780 ZA780 ZA780 OL766 KG907 KG341 RD201 E
#
# 추출옵션 :  2.2
# 질병시작패턴 = "S FG391"
# S FG391 ER119 JV765 QO743 GH433 HK504 ET650 WD100 BN377 TR109 RE397 TR109 WY390 HD433 OK163 QE277 SF108 WD234 HD433 PO203 ET321 FG308 HD405 PL250 WY504 FG391 TY341 KG504 JV766 KO109 QE931 HD405 ER119 UY201 QW987 QO233
#
# 추출옵션 :  2.4
# 질병시작패턴 = "S FG391"
# S FG391 KG907 KG341 PL250 SD388 OP345 IO789 QE277 WR405 WD100 WR896 SD308 IO789 HD405 JV765 LO976 CV305 ER897 PK244 WR321 PO276 ET321 GH700 QO743 RE385 WO900 QO304 OP167 UY112 HK504 RE385 WD599 TR508 WR321 OP345 ET321
#
# 추출옵션 :  2.6
# 질병시작패턴 = "S FG391"
# S FG391 KP321 RE385 QE277 UY503 WY390 PL250 QE931 WR405 OP345 TR675 FG308 ER203 LO976 KG504 ZA107 WY390 KG907 KP345 TR675 ER389 TR675 HD433 KO109 LO976 JV765 ZA107 QO743 FG371 LO103 ER203 RE567 WY107 WD100 QO349 WD100
#
# 반복번호 = 3
# Epoch 1/1
# 179399/179399 [==============================] - 14s 76us/step - loss: 4.0088
#
# 추출옵션 :  1.4
# 질병시작패턴 = "S FG391"
# S FG391 HK377 QE277 QY204 PK244 RD201 TY211 ZA780 WD599 OK211 HD433 OL766 QO102 PL250 E
#
# 추출옵션 :  1.6
# 질병시작패턴 = "S FG391"
# S FG391 ET321 ER389 PK244 BN377 QO304 ZA780 OP345 QE277 RE385 ZA780 KG766 JV766 LO976 ER119 HD433 UY112 RE567 ER203 QY204 TR109 GH791 ZA107 OP167 PK244 PK765 FG371 TY901 PL250 QO233 WO378 WR321 QE277 ET320 TY341 PK213
#
# 추출옵션 :  1.8
# 질병시작패턴 = "S FG391"
# S FG391 OK211 WY390 WO378 OK211 TR508 WY504 E
#
# 추출옵션 :  2.0
# 질병시작패턴 = "S FG391"
# S FG391 TY901 ZA107 WD675 WR896 JV109 ET650 TR675 KG504 BN377 ER119 HD405 CV751 ER897 UY109 ZA780 WD675 KG907 ZA780 WR117 ET650 OK163 PL250 QO349 OP350 SF108 TY211 TR675 KG341 OL766 TR508 TR508 SD398 TR508 HK377 WD100
#
# 추출옵션 :  2.2
# 질병시작패턴 = "S FG391"
# S FG391 QO304 ET321 ER203 SD388 PO276 LO103 TY211 UY980 RE567 RE385 OP350 SF108 ER389 QY204 KP321 E
#
# 추출옵션 :  2.4
# 질병시작패턴 = "S FG391"
# S FG391 PL221 WY504 SD388 TR675 TY341 WR789 JV766 WD100 FG371 QE931 LO103 RD201 ER389 LO976 QW987 SD388 WO208 GH433 KP843 WR405 WR896 LO976 JV765 UY980 KG766 FG391 QO102 PK213 OL344 KO109 PK213 QY204 KP321 TY341 ER119
#
# 추출옵션 :  2.6
# 질병시작패턴 = "S FG391"
# S FG391 PL221 RE397 QW987 RD201 QY204 JV765 TR675 TY341 TR675 OP167 WD599 GH211 CV751 UY112 JV766 RE397 TR109 TR109 UY980 OP167 WD234 ER300 ER119 OL766 SD388 UY201 WR117 WO378 QA107 TR109 OP345 JV109 WR405 WR896 QE277
#
# 반복번호 = 4
# Epoch 1/1
# 179399/179399 [==============================] - 14s 77us/step - loss: 3.9816
#
# 추출옵션 :  1.4
# 질병시작패턴 = "S FG391"
# S FG391 RE397 QO304 FG308 QE931 WO900 WD100 QY204 TR508 CV305 LO103 SF108 SD398 KG766 WO900 ET650 WY504 RE385 GH700 RE577 SF108 TY211 UY980 E
#
# 추출옵션 :  1.6
# 질병시작패턴 = "S FG391"
# S FG391 WO208 WD234 UY201 OP167 ET321 HD405 RE567 E
#
# 추출옵션 :  1.8
# 질병시작패턴 = "S FG391"
# S FG391 RE577 PK244 FG308 QO233 TR675 GH433 WR117 SF108 FG308 ET650 TY341 OP167 PL221 ER300 QO743 KG504 UY201 SF108 RE397 UY980 FG308 PK765 HD433 ER389 HD405 QO102 JV766 CV751 CV751 PO203 JV765 TR109 SD308 IO789 ER897
#
# 추출옵션 :  2.0
# 질병시작패턴 = "S FG391"
# S FG391 SD308 PK765 QE277 PL250 SD398 HD405 ET320 KP321 RE385 CV305 HD405 QO102 KP321 ZA780 TY341 QA107 HK504 TY341 KG341 GH211 HD433 WY504 QE931 QO349 SD308 QO102 RD201 WR789 PL221 TR508 PL890 ZA107 PK244 RE385 TY901
#
# 추출옵션 :  2.2
# 질병시작패턴 = "S FG391"
# S FG391 WR321 ET321 E
#
# 추출옵션 :  2.4
# 질병시작패턴 = "S FG391"
# S FG391 PL890 QO233 PL221 KP321 TY211 WR896 WO208 UY201 KG504 KP843 CV305 ER389 GH433 IO789 QO743 QA107 WO378 KG766 HD405 OP350 WO378 RE567 QO304 UY109 SD388 TR508 HD433 JV765 IO789 WY504 E
#
# 추출옵션 :  2.6
# 질병시작패턴 = "S FG391"
# S FG391 GH433 JV766 IO789 LO103 OK163 ER897 TR109 PL890 UY503 HK504 KP843 PL221 SF108 RE385 WD599 PK244 PL890 QO743 KG504 QW987 PL890 WD100 ER203 KG766 QE931 PK244 KG504 ER389 GH433 QO102 KP345 WR896 WR117 TY211 PK213
#
# 반복번호 = 5
# Epoch 1/1
# 179399/179399 [==============================] - 14s 81us/step - loss: 3.9489
#
# 추출옵션 :  1.4
# 질병시작패턴 = "S FG391"
# S FG391 PL221 KG341 WR789 ER300 OL766 WR117 SD388 WD234 ER119 PL221 SD398 KG907 WO900 PL250 SD388 QO743 QO233 HD433 KG907 ER897 KP345 ER203 WD675 WR321 ER203 UY980 ET650 HK377 E
#
# 추출옵션 :  1.6
# 질병시작패턴 = "S FG391"
# S FG391 QA107 WD675 LO103 RE385 PO203 KG766 PL250 ER203 UY201 QO349 GH791 CV305 QW987 KP321 E
#
# 추출옵션 :  1.8
# 질병시작패턴 = "S FG391"
# S FG391 OK163 ER389 RE397 KG766 FG391 WY390 TY211 QE931 GH433 WY107 OP345 SF108 QE931 ET650 KL365 RE577 WR405 KG504 GH700 OK211 GH700 RD201 KP345 QO102 CV751 RD201 KG907 HK504 KO109 FG391 WD100 KG907 ER119 RE397 KG341
#
# 추출옵션 :  2.0
# 질병시작패턴 = "S FG391"
# S FG391 TY341 OP350 RE577 RE577 GH433 ET650 PK244 HK377 QW987 KP345 QW987 WR405 QO102 KP321 KG504 WO900 WY390 ER119 WR405 QO233 BN377 BN377 IO789 TR675 KP321 PL221 LO103 QO743 PK213 HK504 OK211 OP350 WY504 TY341 OP167
#
# 추출옵션 :  2.2
# 질병시작패턴 = "S FG391"
# S FG391 OL344 KG766 QO743 QO102 TR109 JV109 WR405 WO208 SD308 WY390 SF108 GH433 SD398 KO109 CV751 LO103 WD234 GH700 KP345 FG371 HK377 RE577 WO378 PO203 GH700 ER897 E
#
# 추출옵션 :  2.4
# 질병시작패턴 = "S FG391"
# S FG391 TR508 WY504 ER300 QA107 UY980 RD201 KL365 OL766 UY109 WY107 FG308 PL890 HK377 QO102 WO900 UY109 WD100 IO789 WD675 HD433 KG341 LO103 GH433 KG504 OK163 RE577 KP345 QE931 TY211 WO208 GH433 OK211 ET321 KG766 TR109
#
# 추출옵션 :  2.6
# 질병시작패턴 = "S FG391"
# S FG391 RD201 SD308 ZA780 QE931 WR321 WY107 SD308 KP843 GH791 WR789 CV305 TR508 ER300 KG504 WR896 GH791 KG907 UY109 OP345 UY109 QO102 OL344 TR675 QY204 PK244 WY107 TY901 RE577 KO109 OK211 OK163 FG391 JV109 ZA107 WD234
#
# 반복번호 = 6
# Epoch 1/1
# 179399/179399 [==============================] - 14s 79us/step - loss: 3.9167
#
# 추출옵션 :  1.4
# 질병시작패턴 = "S FG391"
# S FG391 QO102 ER897 E
#
# 추출옵션 :  1.6
# 질병시작패턴 = "S FG391"
# S FG391 GH791 ET320 TR109 TR675 GH791 QY204 WD599 ER897 WD234 GH433 PL250 OK163 WO188 OP167 GH211 QW987 WR789 TY211 WO900 OK211 RE567 GH791 FG391 RE577 LO976 KP843 GH433 WD675 JV109 PO276 OL766 WD234 ET320 HK504 ER897
#
# 추출옵션 :  1.8
# 질병시작패턴 = "S FG391"
# S FG391 QW987 E
#
# 추출옵션 :  2.0
# 질병시작패턴 = "S FG391"
# S FG391 TR109 TY901 PL890 E
#
# 추출옵션 :  2.2
# 질병시작패턴 = "S FG391"
# S FG391 ER389 PL221 HD405 FG308 UY201 GH791 CV751 BN377 KP345 TR109 CV751 HK377 PL250 KL365 QO233 RE577 KG766 FG308 OP350 RE577 GH700 UY109 UY112 WR321 WO378 PL250 KG766 JV766 PL890 UY109 WD675 QA107 PL250 HD405 OK211
#
# 추출옵션 :  2.4
# 질병시작패턴 = "S FG391"
# S FG391 RE397 PO203 QY204 GH791 PL890 JV765 OP167 WO378 TY341 UY112 WR896 UY980 KP843 WD599 CV751 QA107 UY109 WD675 E
#
# 추출옵션 :  2.6
# 질병시작패턴 = "S FG391"
# S FG391 PO276 WO900 KG907 KG504 KG341 ER203 WD100 KG766 HK504 WR117 BN377 QY204 JV765 QE931 HD405 OL766 BN377 PO276 QO743 QO233 GH433 WY504 QO233 HK504 E
#
# 반복번호 = 7
# Epoch 1/1
# 179399/179399 [==============================] - 13s 74us/step - loss: 3.8898
#
# 추출옵션 :  1.4
# 질병시작패턴 = "S FG391"
# S FG391 WO208 KG907 OK211 OP167 WO208 WO900 ET650 KG766 KG504 SD398 HD405 QA107 TY341 OK163 ER897 GH700 UY980 JV766 ER203 OK211 E
#
# 추출옵션 :  1.6
# 질병시작패턴 = "S FG391"
# S FG391 E
#
# 추출옵션 :  1.8
# 질병시작패턴 = "S FG391"
# S FG391 KG766 WD234 RD201 LO976 TR508 PL250 QO743 JV109 FG371 PL250 SD308 SD388 KG341 ER119 E
#
# 추출옵션 :  2.0
# 질병시작패턴 = "S FG391"
# S FG391 PK765 UY503 CV305 GH211 HK504 RD201 HK504 RD201 TR675 WR896 TY211 UY112 OP345 PL250 QO233 KG766 OP167 UY201 WR117 LO103 SD398 WD234 WR117 CV305 UY109 WY107 QO743 KG907 RE385 OP167 PK244 RE567 TY341 WY390 TR675
#
# 추출옵션 :  2.2
# 질병시작패턴 = "S FG391"
# S FG391 WR789 QW987 OP350 KL365 E
#
# 추출옵션 :  2.4
# 질병시작패턴 = "S FG391"
# S FG391 QW987 WD675 CV305 KG504 ET650 LO103 PO276 WO208 UY109 TR675 ER203 BN377 PL221 WR405 RD201 WD100 WD599 JV766 WD675 JV109 QY204 WD675 KG907 ZA107 WD234 TY211 WO188 UY503 TR109 TR109 PK765 WD100 SF108 SF108 UY503
#
# 추출옵션 :  2.6
# 질병시작패턴 = "S FG391"
# S FG391 UY980 JV765 CV751 WY390 WR896 TY211 BN377 WO378 WD675 RD201 KG504 TR109 WY390 KL365 WR321 UY503 WO188 WR117 PL890 PK213 WO188 JV109 RE567 QA107 KO109 PK213 WR117 KG766 WY504 WD234 PL221 E

# %%
avg_price_1year = 0
sum_price = 0 
for i , sent in enumerate(generated_all):
    print(i,sent)
    for str in sent.split(" ")[1:-1]:
        sum_price += dp_code_dic[str]
        
avg_price_1year = round(sum_price / (i+1) , -2) 

print('-'*100)
print('이 분은 앞으로 1년간 총', avg_price_1year, '원의 병원비가 들 예정입니다.')
print('-'*100)
# Out:
# 0 S FG391 HD433 QA107 KG341 WR789 QO233 KP843 ZA780 QA107 WR321 E
# 1 S FG391 WY390 WD100 WD675 QW987 KP321 WR117 QO349 PL890 WO900 WR896 QO743 WD675 E
# 2 S FG391 QA107 TY901 OP350 WR321 HD433 ZA780 LO103 HD405 E
# 3 S FG391 WO188 JV765 QO743 KP345 WO188 TY901 LO976 TY211 OK211 JV765 KG504 WY504 JV766 FG308 WR789 KP843 KG766 JV765 QO349 PK213 TY341 ET320 WR321 ET320 UY980 WR405 PL890 PK213 QE277 LO103 E
# 4 S FG391 GH791 UY109 LO103 LO103 TY341 PO203 WR896 SF108 WY390 ER203 ET321 PK213 HD405 SD398 GH791 QE931 E
# 5 S FG391 WD599 SD398 KP345 PO276 KP321 OP167 E
# 6 S FG391 TR675 LO103 QY204 WD599 OP345 WD599 ET320 HD405 KG504 HK504 UY109 BN377 SF108 JV765 RD201 TY211 KG341 E
# 7 S FG391 JV766 OL766 WD599 QO349 OP350 SD388 QO233 QE931 UY201 TR109 LO103 HD405 LO103 PL890 TY901 OL766 PO203 RD201 KG341 FG371 TR109 WO900 ZA780 ZA780 ZA780 OL766 KG907 KG341 RD201 E
# 8 S FG391 HK377 QE277 QY204 PK244 RD201 TY211 ZA780 WD599 OK211 HD433 OL766 QO102 PL250 E
# 9 S FG391 OK211 WY390 WO378 OK211 TR508 WY504 E
# 10 S FG391 QO304 ET321 ER203 SD388 PO276 LO103 TY211 UY980 RE567 RE385 OP350 SF108 ER389 QY204 KP321 E
# 11 S FG391 RE397 QO304 FG308 QE931 WO900 WD100 QY204 TR508 CV305 LO103 SF108 SD398 KG766 WO900 ET650 WY504 RE385 GH700 RE577 SF108 TY211 UY980 E
# 12 S FG391 WO208 WD234 UY201 OP167 ET321 HD405 RE567 E
# 13 S FG391 WR321 ET321 E
# 14 S FG391 PL890 QO233 PL221 KP321 TY211 WR896 WO208 UY201 KG504 KP843 CV305 ER389 GH433 IO789 QO743 QA107 WO378 KG766 HD405 OP350 WO378 RE567 QO304 UY109 SD388 TR508 HD433 JV765 IO789 WY504 E
# 15 S FG391 PL221 KG341 WR789 ER300 OL766 WR117 SD388 WD234 ER119 PL221 SD398 KG907 WO900 PL250 SD388 QO743 QO233 HD433 KG907 ER897 KP345 ER203 WD675 WR321 ER203 UY980 ET650 HK377 E
# 16 S FG391 QA107 WD675 LO103 RE385 PO203 KG766 PL250 ER203 UY201 QO349 GH791 CV305 QW987 KP321 E
# 17 S FG391 OL344 KG766 QO743 QO102 TR109 JV109 WR405 WO208 SD308 WY390 SF108 GH433 SD398 KO109 CV751 LO103 WD234 GH700 KP345 FG371 HK377 RE577 WO378 PO203 GH700 ER897 E
# 18 S FG391 QO102 ER897 E
# 19 S FG391 QW987 E
# 20 S FG391 TR109 TY901 PL890 E
# 21 S FG391 RE397 PO203 QY204 GH791 PL890 JV765 OP167 WO378 TY341 UY112 WR896 UY980 KP843 WD599 CV751 QA107 UY109 WD675 E
# 22 S FG391 PO276 WO900 KG907 KG504 KG341 ER203 WD100 KG766 HK504 WR117 BN377 QY204 JV765 QE931 HD405 OL766 BN377 PO276 QO743 QO233 GH433 WY504 QO233 HK504 E
# 23 S FG391 WO208 KG907 OK211 OP167 WO208 WO900 ET650 KG766 KG504 SD398 HD405 QA107 TY341 OK163 ER897 GH700 UY980 JV766 ER203 OK211 E
# 24 S FG391 E
# 25 S FG391 KG766 WD234 RD201 LO976 TR508 PL250 QO743 JV109 FG371 PL250 SD308 SD388 KG341 ER119 E
# 26 S FG391 WR789 QW987 OP350 KL365 E
# 27 S FG391 UY980 JV765 CV751 WY390 WR896 TY211 BN377 WO378 WD675 RD201 KG504 TR109 WY390 KL365 WR321 UY503 WO188 WR117 PL890 PK213 WO188 JV109 RE567 QA107 KO109 PK213 WR117 KG766 WY504 WD234 PL221 E
# ----------------------------------------------------------------------------------------------------
# 이 분은 앞으로 1년간 총 623800.0 원의 병원비가 들 예정입니다.
# ----------------------------------------------------------------------------------------------------
